# %% [markdown]
# # #1

# %%
import pandas as pd
data = pd.read_csv("Ch7ExerciseDatacleaned.csv",
                  index_col = "Country Name")
data
# Out:
#                                   2013_GDP_per_Capita  \
# Country Name
# Afghanistan                                   678.671
# Angola                                       5964.473
# Albania                                      4564.518
# United Arab Emirates                        44551.972
# Argentina                                   14708.613
# ...                                               ...
# Republic of Yemen                            1515.946
# South Africa                                 6621.122
# Democratic Republic of the Congo              388.305
# Zambia                                       1845.419
# Zimbabwe                                     1006.825
#
#                                   2013_Life_Expectancy_at_Birth  \
# Country Name
# Afghanistan                                           60.931415
# Angola                                                51.866171
# Albania                                               77.537244
# United Arab Emirates                                  77.131293
# Argentina                                             76.187293
# ...                                                         ...
# Republic of Yemen                                     63.089585
# South Africa                                          56.736585
# Democratic Republic of the Congo                      49.943854
# Zambia                                                58.092780
# Zimbabwe                                              59.773488
#
#                                   2013_Fertility_Rate  2013_Population
# Country Name
# Afghanistan                                     4.900         30682500
# Angola                                          5.863         23448202
# Albania                                         1.771          2897366
# United Arab Emirates                            1.801          9039978
# Argentina                                       2.175         42538304
# ...                                               ...              ...
# Republic of Yemen                               4.075         25533217
# South Africa                                    2.387         53157490
# Democratic Republic of the Congo                5.933         72552861
# Zambia                                          5.687         15246086
# Zimbabwe                                        3.486         14898092
#
# [181 rows x 4 columns]

# %%
import pandas as pd
from stats import *
import numpy as np
from scipy.stats import t, f

class Regression:
    def __init__(self):
        self.stats = stats()
        self.reg_history = {}
        
    def OLS(self, reg_name, data, y_name, beta_names, min_val = 0,
                max_val = None, constant = True):
        self.min_val = min_val
        if max_val != None:
            self.max_val = max_val
        else:
            self.max_val = len(data)
        self.reg_name = reg_name
        self.y_name = y_name
        self.beta_names = beta_names
        self.data = data.copy()
        if constant:
            self.add_constant()
        self.build_matrices()
        self.estimate_betas_and_yhat()
        self.calculate_regression_stats()
        self.save_output()
        
    def add_constant(self):
        self.data["Constant"] = 1
        self.beta_names.append("Constant")
        
    def build_matrices(self):
        #transform dataframes to matrices
        self.y = np.matrix(self.data[self.y_name][self.min_val:self.max_val])
        #create a k X n nested list containg vectors for each exog var
        self.X = np.matrix(self.data[self.beta_names])
        self.X_transpose = np.matrix(self.X).getT()
        #(X'X)**-1
        X_transp_X = np.matmul(self.X_transpose, self.X)
        self.X_transp_X_inv = X_transp_X.getI()
        #X'y
        self.X_transp_y = np.matmul(self.X_transpose, self.y)
    
    def estimate_betas_and_yhat(self):
        #betas = (X'X)**-1 * X'y
        self.betas = np.matmul(self.X_transp_X_inv, self.X_transp_y)
        #y_hat = X * betas
        self.y_hat = np.matmul(self.X, self.betas)
        #create a column that holds y_hat values
        self.data[self.y_name[0] + " estimator"] = \
            [i.item(0) for i in self.y_hat]
        #create a table that holds the estimated coefficient
        #as well as the standard errors, tstats,and pvalues
        self.estimates = pd.DataFrame(self.betas, index = self.beta_names,
                                      columns = ["Coefficient"])
        #id y variable in index
        self.estimates.index.name = "y = " + self.y_name[0]
        
    def calculate_regression_stats(self):
        self.sum_square_stats()
        self.calculate_degrees_of_freedom()
        self.calculate_estimator_variance()
        self.calculate_covariance_matrix()
        self.calculate_t_p_error_stats()
        self.calculate_root_MSE()
        self.calculate_rsquared()
        self.calculate_fstat()
        self.build_stats_DF()
    
    def sum_square_stats(self):
        ssr_list = []
        sse_list = []
        sst_list = []
        mean_y = self.stats.mean(self.y).item(0)
        for i in range(len(self.y)):
            #ssr is sum of squared distances between the estimated y values
            #(y_hat) and the average of y values (y_bar or simply mean_y)
            yhat_i = self.y_hat[i]
            y_i = self.y[i]
            ssr_list.append((yhat_i - mean_y) ** 2)
            sse_list.append((y_i - yhat_i) ** 2)
            sst_list.append((y_i - mean_y) ** 2)
            #calling the item calls the value instead of matrix
            self.ssr = self.stats.total(ssr_list).item(0)
            self.sst = self.stats.total(sst_list).item(0)
            self.sse = self.stats.total(sse_list).item(0)

    def calculate_degrees_of_freedom(self):
        #df compares the num of observs to the num
        #exog variables used to form the prediction
        self.lost_degrees_of_freedom = len(self.estimates)
        self.num_obs = self.max_val + 1 - self.min_val
        self.degrees_of_freedom =  self.num_obs - self.lost_degrees_of_freedom
        
    def calculate_estimator_variance(self):
        #estimator variance is the sse normalized by the degrees of freedom
        #so it increases as the number of exog vars used in estimating increase
        #that is, as degrees of freedom fall
        self.estimator_variance = self.sse / self.degrees_of_freedom
        
    def calculate_covariance_matrix(self):
        #cov matrix will be used to estimate standard errors for ea coeff
        #estimator var * (X'X)**-1 is the cov matrix
        self.cov_matrix = float(self.estimator_variance) * self.X_transp_X_inv
        self.cov_matrix = pd.DataFrame(self.cov_matrix, 
                                       columns = self.beta_names,
                                       index = self.beta_names)
    
    def calculate_t_p_error_stats(self):
        self.rating_dict = {.05:"*",
                       .01:"**",
                       .001: "***"}
        results = self.estimates
        stat_sig_names = ["SE", "t-stat", "p-value"]
        for stat_name in stat_sig_names: 
            results[stat_name] = np.nan
        #generate statistic for each variable
        for var in self.beta_names:
            #SE of coefficient is found in the diagonal of cov_matrix
            results.loc[var]["SE"] = self.cov_matrix[var][var] ** (1/2)
            #tstat = Coeff / SE
            results.loc[var]["t-stat"] = \
                results["Coefficient"][var] / results["SE"][var]
            #p-value is estimated using a  table that transforms t-value in refference to df
            results.loc[var]["p-value"] = np.round(t.sf(np.abs(results.\
                       loc[var]["t-stat"]),self.degrees_of_freedom + 1) * 2, 5)
        #values for signifiances will be blank unless p-value < .05
        #pandas does not allow np.nan values or default blank strings to be replaced
        significance = ["" for i in range(len(self.beta_names))]   
        for i in range(len(self.beta_names)):
            var = self.beta_names[i]
            for val in self.rating_dict:
                if results.loc[var]["p-value"] < val:
                    significance[i] = self.rating_dict[val]
                    print(var, self.rating_dict[val])  
        results["significance"] = significance
        
    def calculate_root_MSE(self):
        self.root_mse = self.estimator_variance ** (1/2)
    
    def calculate_rsquared(self):
        self.r_sq = self.ssr / self.sst
        self.adj_r_sq = 1 - self.sse / self.degrees_of_freedom / (self.sst\
                             / (self.num_obs - 1))
    
    def calculate_fstat(self):
        self.f_stat = (self.sst - self.sse) / (self.lost_degrees_of_freedom\
                       - 1) / self.estimator_variance
    
    def build_stats_DF(self):
        stats_dict = {"r**2": [self.r_sq],
                      "Adj. r**2": [self.adj_r_sq],
                      "f-stat": [self.f_stat],
                      "EST Var": [self.estimator_variance],
                      "MSE": [self.root_mse],
                      "SSE": [self.sse],
                      "SSR": [self.ssr],
                      "SST": [self.sst],
                      "Obs.": [self.num_obs],
                      "DOF":[self.degrees_of_freedom]}
        self.stats_DF = pd.DataFrame(stats_dict)
        self.stats_DF = self.stats_DF.rename(index={0:"Estimation Statistics"})
        self.stats_DF = self.stats_DF.T

    def save_output(self):
        self.reg_history[self.reg_name] = {}
        self.reg_history[self.reg_name]["Reg Stats"] = self.stats_DF.copy()
        self.reg_history[self.reg_name]["Estimates"]= self.estimates.copy()
        self.reg_history[self.reg_name]["Cov Matrix"] = self.cov_matrix.copy()

# %%
#from regression import Regresssion
reg = Regression()
print(reg)
# Out:
# You created an instance of stats()
# <__main__.Regression object at 0x000002771AAFFD00>

# %%
y_var = ["2013_GDP_per_Capita"]
x_vars = ["2013_Life_Expectancy_at_Birth", "2013_Fertility_Rate", "2013_Population"]

reg.OLS("GDP per Capita", data, y_var, x_vars)
# Out:
# 2013_Life_Expectancy_at_Birth *
# 2013_Life_Expectancy_at_Birth **
# 2013_Life_Expectancy_at_Birth ***
# Constant *
# Constant **
# Constant ***

# %%
reg.betas
# Out:
# matrix([[ 1.44752677e+03],
#         [ 1.43821845e+03],
#         [-6.88643103e-06],
#         [-9.18051164e+04]])

# %%
reg.estimates.to_csv("hmwkResults.csv")
reg.estimates
# Out:
#                                 Coefficient            SE    t-stat  p-value  \
# y = 2013_GDP_per_Capita
# 2013_Life_Expectancy_at_Birth   1447.526770    227.953261  6.350103  0.00000
# 2013_Fertility_Rate             1438.218449   1489.589099  0.965514  0.33559
# 2013_Population                   -0.000007      0.000008 -0.816702  0.41518
# Constant                      -91805.116447  19714.952999 -4.656624  0.00001
#
#                               significance
# y = 2013_GDP_per_Capita
# 2013_Life_Expectancy_at_Birth          ***
# 2013_Fertility_Rate
# 2013_Population
# Constant                               ***

# %%
reg.ssr, reg.sse, reg.sst
# Out:
# (24643785778.36878, 46026153888.5291, 70669939666.8977)

# %%
reg.cov_matrix.to_csv("hmwkCovMatrix.csv")
reg.cov_matrix
# Out:
#                                2013_Life_Expectancy_at_Birth  \
# 2013_Life_Expectancy_at_Birth                   5.196269e+04
# 2013_Fertility_Rate                             2.780520e+05
# 2013_Population                                 1.304148e-04
# Constant                                       -4.450097e+06
#
#                                2013_Fertility_Rate  2013_Population  \
# 2013_Life_Expectancy_at_Birth         2.780520e+05     1.304148e-04
# 2013_Fertility_Rate                   2.218876e+06     1.189335e-03
# 2013_Population                       1.189335e-03     7.109854e-11
# Constant                             -2.591300e+07    -1.533340e-02
#
#                                    Constant
# 2013_Life_Expectancy_at_Birth -4.450097e+06
# 2013_Fertility_Rate           -2.591300e+07
# 2013_Population               -1.533340e-02
# Constant                       3.886794e+08

# %%
reg.stats_DF.to_csv("hmwkStatistics.csv")
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                3.487167e-01
# Adj. r**2           3.377400e-01
# f-stat              3.176885e+01
# EST Var             2.585739e+08
# MSE                 1.608023e+04
# SSE                 4.602615e+10
# SSR                 2.464379e+10
# SST                 7.066994e+10
# Obs.                1.820000e+02
# DOF                 1.780000e+02

# %% [markdown]
# # #2

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

def plot_scatter_with_estimator(title, data, x_vars, y_var, pp = None):
    #set default font size
    plt.rcParams.update({"font.size":19})
    #use a for loop to call each exogenous variable
    y = y_var[0]
    for x in x_vars:  
        #prepare a figure with the predictor
        #ax signifies they are in the same plot
        fig, ax = plt.subplots(figsize=(12,8))  
        #put the labels in the legend  
        y_label1 = "Estimate"  
        y_label2 = "Observation"  
        #plot the estimated value 
        data.plot.scatter(x = x, y = y + " estimator", ax = ax, c = "r", 
                          s = 10, label = y_label1, legend = False)  
        #erase the y_axis label so that "estimator" is not shown 
        plt.ylabel("")  
        data.plot.scatter(x = x, y = y, ax = ax, s = 10, label = y_label2,  
                          legend = False)  
        #put the legend to the top left
        #bbox_to_anchor will specify the exact placement
        plt.legend(loc = "upper left", labels = [y_label1, y_label2],   
                   bbox_to_anchor = (0, 1.17))  
        plt.title("Observations and\nOLS Estimates")
        #remove tick lines
        ax.xaxis.set_ticks_position('none')  
        ax.yaxis.set_ticks_position('none')   
        if pp != None: pp.savefig(fig, bbox_inches = "tight")
        
pp = PdfPages("HmwkRegressionPlots.pdf")
plot_scatter_with_estimator("Plot", reg.data, x_vars, y_var)

pp.close()

# %% [markdown]
# # #3

# %%
import pandas as pd
log_DF = pd.DataFrame(data)
log_DF
# Out:
#                                   2013_GDP_per_Capita  \
# Country Name
# Afghanistan                                   678.671
# Angola                                       5964.473
# Albania                                      4564.518
# United Arab Emirates                        44551.972
# Argentina                                   14708.613
# ...                                               ...
# Republic of Yemen                            1515.946
# South Africa                                 6621.122
# Democratic Republic of the Congo              388.305
# Zambia                                       1845.419
# Zimbabwe                                     1006.825
#
#                                   2013_Life_Expectancy_at_Birth  \
# Country Name
# Afghanistan                                           60.931415
# Angola                                                51.866171
# Albania                                               77.537244
# United Arab Emirates                                  77.131293
# Argentina                                             76.187293
# ...                                                         ...
# Republic of Yemen                                     63.089585
# South Africa                                          56.736585
# Democratic Republic of the Congo                      49.943854
# Zambia                                                58.092780
# Zimbabwe                                              59.773488
#
#                                   2013_Fertility_Rate  2013_Population
# Country Name
# Afghanistan                                     4.900         30682500
# Angola                                          5.863         23448202
# Albania                                         1.771          2897366
# United Arab Emirates                            1.801          9039978
# Argentina                                       2.175         42538304
# ...                                               ...              ...
# Republic of Yemen                               4.075         25533217
# South Africa                                    2.387         53157490
# Democratic Republic of the Congo                5.933         72552861
# Zambia                                          5.687         15246086
# Zimbabwe                                        3.486         14898092
#
# [181 rows x 4 columns]

# %%
log_DF['GDP_Per_Capita_log_value']=np.log(log_DF['2013_GDP_per_Capita'])
log_DF['Life_Expectancy_at_Birth_log_value']=np.log(log_DF['2013_Life_Expectancy_at_Birth'])
log_DF['Fertility_Rate_log_value']=np.log(log_DF['2013_Fertility_Rate'])
log_DF['Population_log_value']=np.log(log_DF['2013_Population'])
log_DF.to_csv("hmwk2logvalues.csv")
log_DF
# Out:
#                                   2013_GDP_per_Capita  \
# Country Name
# Afghanistan                                   678.671
# Angola                                       5964.473
# Albania                                      4564.518
# United Arab Emirates                        44551.972
# Argentina                                   14708.613
# ...                                               ...
# Republic of Yemen                            1515.946
# South Africa                                 6621.122
# Democratic Republic of the Congo              388.305
# Zambia                                       1845.419
# Zimbabwe                                     1006.825
#
#                                   2013_Life_Expectancy_at_Birth  \
# Country Name
# Afghanistan                                           60.931415
# Angola                                                51.866171
# Albania                                               77.537244
# United Arab Emirates                                  77.131293
# Argentina                                             76.187293
# ...                                                         ...
# Republic of Yemen                                     63.089585
# South Africa                                          56.736585
# Democratic Republic of the Congo                      49.943854
# Zambia                                                58.092780
# Zimbabwe                                              59.773488
#
#                                   2013_Fertility_Rate  2013_Population  \
# Country Name
# Afghanistan                                     4.900         30682500
# Angola                                          5.863         23448202
# Albania                                         1.771          2897366
# United Arab Emirates                            1.801          9039978
# Argentina                                       2.175         42538304
# ...                                               ...              ...
# Republic of Yemen                               4.075         25533217
# South Africa                                    2.387         53157490
# Democratic Republic of the Congo                5.933         72552861
# Zambia                                          5.687         15246086
# Zimbabwe                                        3.486         14898092
#
#                                   GDP_Per_Capita_log_value  \
# Country Name
# Afghanistan                                       6.520136
# Angola                                            8.693576
# Albania                                           8.426068
# United Arab Emirates                             10.704412
# Argentina                                         9.596189
# ...                                                    ...
# Republic of Yemen                                 7.323795
# South Africa                                      8.798020
# Democratic Republic of the Congo                  5.961791
# Zambia                                            7.520462
# Zimbabwe                                          6.914557
#
#                                   Life_Expectancy_at_Birth_log_value  \
# Country Name
# Afghanistan                                                 4.109749
# Angola                                                      3.948667
# Albania                                                     4.350758
# United Arab Emirates                                        4.345509
# Argentina                                                   4.333195
# ...                                                              ...
# Republic of Yemen                                           4.144556
# South Africa                                                4.038419
# Democratic Republic of the Congo                            3.910899
# Zambia                                                      4.062041
# Zimbabwe                                                    4.090562
#
#                                   Fertility_Rate_log_value  \
# Country Name
# Afghanistan                                       1.589235
# Angola                                            1.768661
# Albania                                           0.571544
# United Arab Emirates                              0.588342
# Argentina                                         0.777029
# ...                                                    ...
# Republic of Yemen                                 1.404871
# South Africa                                      0.870037
# Democratic Republic of the Congo                  1.780530
# Zambia                                            1.738183
# Zimbabwe                                          1.248755
#
#                                   Population_log_value
# Country Name
# Afghanistan                                  17.239203
# Angola                                       16.970304
# Albania                                      14.879313
# United Arab Emirates                         16.017167
# Argentina                                    17.565915
# ...                                                ...
# Republic of Yemen                            17.055491
# South Africa                                 17.788770
# Democratic Republic of the Congo             18.099826
# Zambia                                       16.539833
# Zimbabwe                                     16.516744
#
# [181 rows x 8 columns]

# %% [markdown]
# # #4

# %%
import pandas as pd
from stats import *
import numpy as np
from scipy.stats import t, f

class Regression:
    def __init__(self):
        self.stats = stats()
        self.reg_history = {}
        
    def OLS(self, reg_name, data, y_name, beta_names, min_val = 0,
                max_val = None, constant = True):
        self.min_val = min_val
        if max_val != None:
            self.max_val = max_val
        else:
            self.max_val = len(data)
        self.reg_name = reg_name
        self.y_name = y_name
        self.beta_names = beta_names
        self.data = data.copy()
        if constant:
            self.add_constant()
        self.build_matrices()
        self.estimate_betas_and_yhat()
        self.calculate_regression_stats()
        self.save_output()
        
    def add_constant(self):
        self.data["Constant"] = 1
        self.beta_names.append("Constant")
        
    def build_matrices(self):
        #transform dataframes to matrices
        self.y = np.matrix(self.data[self.y_name][self.min_val:self.max_val])
        #create a k X n nested list containg vectors for each exog var
        self.X = np.matrix(self.data[self.beta_names])
        self.X_transpose = np.matrix(self.X).getT()
        #(X'X)**-1
        X_transp_X = np.matmul(self.X_transpose, self.X)
        self.X_transp_X_inv = X_transp_X.getI()
        #X'y
        self.X_transp_y = np.matmul(self.X_transpose, self.y)
    
    def estimate_betas_and_yhat(self):
        #betas = (X'X)**-1 * X'y
        self.betas = np.matmul(self.X_transp_X_inv, self.X_transp_y)
        #y_hat = X * betas
        self.y_hat = np.matmul(self.X, self.betas)
        #create a column that holds y_hat values
        self.data[self.y_name[0] + " estimator"] = \
            [i.item(0) for i in self.y_hat]
        #create a table that holds the estimated coefficient
        #as well as the standard errors, tstats,and pvalues
        self.estimates = pd.DataFrame(self.betas, index = self.beta_names,
                                      columns = ["Coefficient"])
        #id y variable in index
        self.estimates.index.name = "y = " + self.y_name[0]
        
    def calculate_regression_stats(self):
        self.sum_square_stats()
        self.calculate_degrees_of_freedom()
        self.calculate_estimator_variance()
        self.calculate_covariance_matrix()
        self.calculate_t_p_error_stats()
        self.calculate_root_MSE()
        self.calculate_rsquared()
        self.calculate_fstat()
        self.build_stats_DF()
    
    def sum_square_stats(self):
        ssr_list = []
        sse_list = []
        sst_list = []
        mean_y = self.stats.mean(self.y).item(0)
        for i in range(len(self.y)):
            #ssr is sum of squared distances between the estimated y values
            #(y_hat) and the average of y values (y_bar or simply mean_y)
            yhat_i = self.y_hat[i]
            y_i = self.y[i]
            ssr_list.append((yhat_i - mean_y) ** 2)
            sse_list.append((y_i - yhat_i) ** 2)
            sst_list.append((y_i - mean_y) ** 2)
            #calling the item calls the value instead of matrix
            self.ssr = self.stats.total(ssr_list).item(0)
            self.sst = self.stats.total(sst_list).item(0)
            self.sse = self.stats.total(sse_list).item(0)

    def calculate_degrees_of_freedom(self):
        #df compares the num of observs to the num
        #exog variables used to form the prediction
        self.lost_degrees_of_freedom = len(self.estimates)
        self.num_obs = self.max_val + 1 - self.min_val
        self.degrees_of_freedom =  self.num_obs - self.lost_degrees_of_freedom
        
    def calculate_estimator_variance(self):
        #estimator variance is the sse normalized by the degrees of freedom
        #so it increases as the number of exog vars used in estimating increase
        #that is, as degrees of freedom fall
        self.estimator_variance = self.sse / self.degrees_of_freedom
        
    def calculate_covariance_matrix(self):
        #cov matrix will be used to estimate standard errors for ea coeff
        #estimator var * (X'X)**-1 is the cov matrix
        self.cov_matrix = float(self.estimator_variance) * self.X_transp_X_inv
        self.cov_matrix = pd.DataFrame(self.cov_matrix, 
                                       columns = self.beta_names,
                                       index = self.beta_names)
    
    def calculate_t_p_error_stats(self):
        self.rating_dict = {.05:"*",
                       .01:"**",
                       .001: "***"}
        results = self.estimates
        stat_sig_names = ["SE", "t-stat", "p-value"]
        for stat_name in stat_sig_names: 
            results[stat_name] = np.nan
        #generate statistic for each variable
        for var in self.beta_names:
            #SE of coefficient is found in the diagonal of cov_matrix
            results.loc[var]["SE"] = self.cov_matrix[var][var] ** (1/2)
            #tstat = Coeff / SE
            results.loc[var]["t-stat"] = \
                results["Coefficient"][var] / results["SE"][var]
            #p-value is estimated using a  table that transforms t-value in refference to df
            results.loc[var]["p-value"] = np.round(t.sf(np.abs(results.\
                       loc[var]["t-stat"]),self.degrees_of_freedom + 1) * 2, 5)
        #values for signifiances will be blank unless p-value < .05
        #pandas does not allow np.nan values or default blank strings to be replaced
        significance = ["" for i in range(len(self.beta_names))]   
        for i in range(len(self.beta_names)):
            var = self.beta_names[i]
            for val in self.rating_dict:
                if results.loc[var]["p-value"] < val:
                    significance[i] = self.rating_dict[val]
                    print(var, self.rating_dict[val])  
        results["significance"] = significance
        
    def calculate_root_MSE(self):
        self.root_mse = self.estimator_variance ** (1/2)
    
    def calculate_rsquared(self):
        self.r_sq = self.ssr / self.sst
        self.adj_r_sq = 1 - self.sse / self.degrees_of_freedom / (self.sst\
                             / (self.num_obs - 1))
    
    def calculate_fstat(self):
        self.f_stat = (self.sst - self.sse) / (self.lost_degrees_of_freedom\
                       - 1) / self.estimator_variance
    
    def build_stats_DF(self):
        stats_dict = {"r**2": [self.r_sq],
                      "Adj. r**2": [self.adj_r_sq],
                      "f-stat": [self.f_stat],
                      "EST Var": [self.estimator_variance],
                      "MSE": [self.root_mse],
                      "SSE": [self.sse],
                      "SSR": [self.ssr],
                      "SST": [self.sst],
                      "Obs.": [self.num_obs],
                      "DOF":[self.degrees_of_freedom]}
        self.stats_DF = pd.DataFrame(stats_dict)
        self.stats_DF = self.stats_DF.rename(index={0:"Estimation Statistics"})
        self.stats_DF = self.stats_DF.T

    def save_output(self):
        self.reg_history[self.reg_name] = {}
        self.reg_history[self.reg_name]["Reg Stats"] = self.stats_DF.copy()
        self.reg_history[self.reg_name]["Estimates"]= self.estimates.copy()
        self.reg_history[self.reg_name]["Cov Matrix"] = self.cov_matrix.copy()

# %%
reg = Regression()
print(reg)
# Out:
# You created an instance of stats()
# <__main__.Regression object at 0x000002771D2B9A60>

# %%
y_var = ["GDP_Per_Capita_log_value"]
x_vars = ["Life_Expectancy_at_Birth_log_value", "Fertility_Rate_log_value", "Population_log_value"]

reg.OLS("Logged GDP per Capita", data, y_var, x_vars)
# Out:
# Life_Expectancy_at_Birth_log_value *
# Life_Expectancy_at_Birth_log_value **
# Life_Expectancy_at_Birth_log_value ***
# Fertility_Rate_log_value *
# Fertility_Rate_log_value **
# Fertility_Rate_log_value ***
# Constant *

# %%
reg.betas
# Out:
# matrix([[ 4.75193143],
#         [-1.17276933],
#         [-0.05412989],
#         [-9.6167461 ]])

# %%
reg.estimates.to_csv("hmwkLOGResults.csv")
reg.estimates
# Out:
#                                     Coefficient        SE    t-stat  p-value  \
# y = GDP_Per_Capita_log_value
# Life_Expectancy_at_Birth_log_value     4.751931  0.815057  5.830181  0.00000
# Fertility_Rate_log_value              -1.172769  0.245736 -4.772481  0.00000
# Population_log_value                  -0.054130  0.035305 -1.533205  0.12699
# Constant                              -9.616746  3.733373 -2.575887  0.01081
#
#                                    significance
# y = GDP_Per_Capita_log_value
# Life_Expectancy_at_Birth_log_value          ***
# Fertility_Rate_log_value                    ***
# Population_log_value
# Constant                                      *

# %%
reg.ssr, reg.sse, reg.sst
# Out:
# (239.23237955610412, 145.22295076379194, 384.4553303197233)

# %%
reg.cov_matrix.to_csv("hmwkLOGCovMatrix.csv")
reg.cov_matrix
# Out:
#                                     Life_Expectancy_at_Birth_log_value  \
# Life_Expectancy_at_Birth_log_value                            0.664318
# Fertility_Rate_log_value                                      0.161148
# Population_log_value                                          0.002321
# Constant                                                     -3.006730
#
#                                     Fertility_Rate_log_value  \
# Life_Expectancy_at_Birth_log_value                  0.161148
# Fertility_Rate_log_value                            0.060386
# Population_log_value                                0.000470
# Constant                                           -0.747836
#
#                                     Population_log_value   Constant
# Life_Expectancy_at_Birth_log_value              0.002321  -3.006730
# Fertility_Rate_log_value                        0.000470  -0.747836
# Population_log_value                            0.001246  -0.029982
# Constant                                       -0.029982  13.938074

# %%
reg.stats_DF.to_csv("hmwkLOGStatistics.csv")
reg.stats_DF
# Out:
#            Estimation Statistics
# r**2                    0.622263
# Adj. r**2               0.615897
# f-stat                 97.742502
# EST Var                 0.815859
# MSE                     0.903249
# SSE                   145.222951
# SSR                   239.232380
# SST                   384.455330
# Obs.                  182.000000
# DOF                   178.000000

# %% [markdown]
# # EXPLAIN THE CHANGE

# %% [markdown]
# # #5

# %%
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages

def plot_scatter_with_estimator(title, data, x_vars, y_var, pp = None):
    #set default font size
    plt.rcParams.update({"font.size":19})
    #use a for loop to call each exogenous variable
    y = y_var[0]
    for x in x_vars:  
        #prepare a figure with the predictor
        #ax signifies they are in the same plot
        fig, ax = plt.subplots(figsize=(12,8))  
        #put the labels in the legend  
        y_label1 = "Estimate"  
        y_label2 = "Observation"  
        #plot the estimated value 
        data.plot.scatter(x = x, y = y + " estimator", ax = ax, c = "r", 
                          s = 10, label = y_label1, legend = False)  
        #erase the y_axis label so that "estimator" is not shown 
        plt.ylabel("")  
        data.plot.scatter(x = x, y = y, ax = ax, s = 10, label = y_label2,  
                          legend = False)  
        #put the legend to the top left
        #bbox_to_anchor will specify the exact placement
        plt.legend(loc = "upper left", labels = [y_label1, y_label2],   
                   bbox_to_anchor = (0, 1.17))  
        plt.title("Observations and\nOLS Estimates")
        #remove tick lines
        ax.xaxis.set_ticks_position('none')  
        ax.yaxis.set_ticks_position('none')   
        if pp != None: pp.savefig(fig, bbox_inches = "tight")
        
pp = PdfPages("HmwkLOGRegressionPlots.pdf")
plot_scatter_with_estimator("Plot", reg.data, x_vars, y_var)

pp.close()

# %% [markdown]
# # #6
